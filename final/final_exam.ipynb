# %%
import pandas as pd

# %%
df=pd.read_csv('Indian_Kids_Screen_Time.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Urban_or_Rural                     9712 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 540.7+ KB

# %%
for col in df.columns:
    if df[col].dtype=='object':
        if df[col].nunique()<=10:
            dummies=pd.get_dummies(df[col],prefix=col, dtype=int)
            df=pd.concat([df.drop(columns=[col]),dummies],axis=1)
        else:
            df[col]=encoder.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  2   Exceeded_Recommended_Limit         9712 non-null   bool
#  3   Educational_to_Recreational_Ratio  9712 non-null   float64
#  4   Health_Impacts                     9712 non-null   int64
#  5   Gender_Female                      9712 non-null   int64
#  6   Gender_Male                        9712 non-null   int64
#  7   Primary_Device_Laptop              9712 non-null   int64
#  8   Primary_Device_Smartphone          9712 non-null   int64
#  9   Primary_Device_TV                  9712 non-null   int64
#  10  Primary_Device_Tablet              9712 non-null   int64
# ...

# %%
df.head()
# Out:
#    Age  Avg_Daily_Screen_Time_hr  Exceeded_Recommended_Limit  \
# 0   14                      3.99                        True
# 1   11                      4.61                        True
# 2   18                      3.73                        True
# 3   15                      1.21                       False
# 4   12                      5.89                        True
#
#    Educational_to_Recreational_Ratio  Health_Impacts  Gender_Female  \
# 0                               0.42              10              0
# 1                               0.30               7              1
# 2                               0.32               7              1
# 3                               0.39              15              1
# 4                               0.49               8              1
#
#    Gender_Male  Primary_Device_Laptop  Primary_Device_Smartphone  \
# 0            1                      0                          1
# ...

# %%
value_mapping = {
    'True' : 0,
    'False' : 1
}

df['colm_ordinal'] = df['Exceeded_Recommended_Limit'].map(value_mapping)

# %%
df.drop('Exceeded_Recommended_Limit',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  2   Educational_to_Recreational_Ratio  9712 non-null   float64
#  3   Health_Impacts                     9712 non-null   int64
#  4   Gender_Female                      9712 non-null   int64
#  5   Gender_Male                        9712 non-null   int64
#  6   Primary_Device_Laptop              9712 non-null   int64
#  7   Primary_Device_Smartphone          9712 non-null   int64
#  8   Primary_Device_TV                  9712 non-null   int64
#  9   Primary_Device_Tablet              9712 non-null   int64
#  10  Urban_or_Rural_Rural               9712 non-null   int64
# ...

# %%
df.head()
# Out:
#    Age  Avg_Daily_Screen_Time_hr  Educational_to_Recreational_Ratio  \
# 0   14                 -0.211179                          -0.098694
# 1   11                  0.149675                          -1.737647
# 2   18                 -0.362506                          -1.464488
# 3   15                 -1.829204                          -0.508432
# 4   12                  0.894665                           0.857362
#
#    Health_Impacts  Gender_Female  Gender_Male  Primary_Device_Laptop  \
# 0              10              0            1                      0
# 1               7              1            0                      1
# 2               7              1            0                      0
# 3              15              1            0                      1
# 4               8              1            0                      0
#
#    Primary_Device_Smartphone  Primary_Device_TV  Primary_Device_Tablet  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  2   Educational_to_Recreational_Ratio  9712 non-null   float64
#  3   Health_Impacts                     9712 non-null   int64
#  4   Gender_Female                      9712 non-null   int64
#  5   Gender_Male                        9712 non-null   int64
#  6   Primary_Device_Laptop              9712 non-null   int64
#  7   Primary_Device_Smartphone          9712 non-null   int64
#  8   Primary_Device_TV                  9712 non-null   int64
#  9   Primary_Device_Tablet              9712 non-null   int64
#  10  Urban_or_Rural_Rural               9712 non-null   int64
# ...

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
standart=StandardScaler()
minmax=MinMaxScaler()
robust=RobustScaler()

# %%
ustun=df.select_dtypes(include=['float64','int32']).columns.tolist()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  2   Educational_to_Recreational_Ratio  9712 non-null   float64
#  3   Health_Impacts                     9712 non-null   int64
#  4   Gender_Female                      9712 non-null   int64
#  5   Gender_Male                        9712 non-null   int64
#  6   Primary_Device_Laptop              9712 non-null   int64
#  7   Primary_Device_Smartphone          9712 non-null   int64
#  8   Primary_Device_TV                  9712 non-null   int64
#  9   Primary_Device_Tablet              9712 non-null   int64
#  10  Urban_or_Rural_Rural               9712 non-null   int64
# ...

# %%
df[ustun]=standart.fit_transform(df[ustun])
# Out:
# C:\Users\akobi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\akobi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# C:\Users\akobi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %%
df.head()
# Out:
#    Age  Avg_Daily_Screen_Time_hr  Educational_to_Recreational_Ratio  \
# 0   14                 -0.211179                          -0.098694
# 1   11                  0.149675                          -1.737647
# 2   18                 -0.362506                          -1.464488
# 3   15                 -1.829204                          -0.508432
# 4   12                  0.894665                           0.857362
#
#    Health_Impacts  Gender_Female  Gender_Male  Primary_Device_Laptop  \
# 0              10              0            1                      0
# 1               7              1            0                      1
# 2               7              1            0                      0
# 3              15              1            0                      1
# 4               8              1            0                      0
#
#    Primary_Device_Smartphone  Primary_Device_TV  Primary_Device_Tablet  \
# ...

# %% [markdown]
# MinMax

# %%
df[ustun]=minmax.fit_transform(df[ustun])
# Out:
# C:\Users\akobi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\_array_api.py:686: RuntimeWarning: All-NaN slice encountered
#   return xp.asarray(numpy.nanmin(X, axis=axis))
# C:\Users\akobi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\_array_api.py:706: RuntimeWarning: All-NaN slice encountered
#   return xp.asarray(numpy.nanmax(X, axis=axis))

# %%
df.head()
# Out:
#    Age  Avg_Daily_Screen_Time_hr  Educational_to_Recreational_Ratio  \
# 0   14                  0.287257                           0.400000
# 1   11                  0.331893                           0.000000
# 2   18                  0.268539                           0.066667
# 3   15                  0.087113                           0.300000
# 4   12                  0.424046                           0.633333
#
#    Health_Impacts  Gender_Female  Gender_Male  Primary_Device_Laptop  \
# 0              10              0            1                      0
# 1               7              1            0                      1
# 2               7              1            0                      0
# 3              15              1            0                      1
# 4               8              1            0                      0
#
#    Primary_Device_Smartphone  Primary_Device_TV  Primary_Device_Tablet  \
# ...

# %% [markdown]
# Robust

# %%
df[ustun]=robust.fit_transform(df[ustun])
# Out:
# C:\Users\akobi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\numpy\lib\_nanfunctions_impl.py:1216: RuntimeWarning: All-NaN slice encountered
#   return fnb._ureduce(a, func=_nanmedian, keepdims=keepdims,
# C:\Users\akobi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\numpy\lib\_nanfunctions_impl.py:1406: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(

# %%
df.head()
# Out:
#    Age  Avg_Daily_Screen_Time_hr  Educational_to_Recreational_Ratio  \
# 0   14                 -0.228426                          -0.090909
# 1   11                  0.086294                          -1.181818
# 2   18                 -0.360406                          -1.000000
# 3   15                 -1.639594                          -0.363636
# 4   12                  0.736041                           0.545455
#
#    Health_Impacts  Gender_Female  Gender_Male  Primary_Device_Laptop  \
# 0              10              0            1                      0
# 1               7              1            0                      1
# 2               7              1            0                      0
# 3              15              1            0                      1
# 4               8              1            0                      0
#
#    Primary_Device_Smartphone  Primary_Device_TV  Primary_Device_Tablet  \
# ...
